# %%
# !pip install medmnist
# Out:
# Collecting medmnist
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from medmnist) (2.2.6)
# Requirement already satisfied: pandas in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from medmnist) (2.2.2)
# Requirement already satisfied: scikit-learn in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from medmnist) (1.7.2)
# Requirement already satisfied: scikit-image in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from medmnist) (0.25.2)
# Requirement already satisfied: tqdm in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from medmnist) (4.67.1)
# Requirement already satisfied: Pillow in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from medmnist) (12.0.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torch in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from medmnist) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from medmnist) (0.21.0+cu124)
# Requirement already satisfied: termcolor in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from fire->medmnist) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from pandas->medmnist) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from pandas->medmnist) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from pandas->medmnist) (2025.2)
# Requirement already satisfied: six>=1.5 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->medmnist) (1.17.0)
# Requirement already satisfied: scipy>=1.11.4 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from scikit-image->medmnist) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from scikit-image->medmnist) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from scikit-image->medmnist) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from scikit-image->medmnist) (2025.5.10)
# Requirement already satisfied: packaging>=21 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from scikit-image->medmnist) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from scikit-image->medmnist) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from scikit-learn->medmnist) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from scikit-learn->medmnist) (3.6.0)
# Requirement already satisfied: filelock in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (4.15.0)
# Requirement already satisfied: jinja2 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (3.1.6)
# Requirement already satisfied: fsspec in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from torch->medmnist) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from sympy==1.13.1->torch->medmnist) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /data4/baihexiang/conda_envs/biomedparse_v2/lib/python3.10/site-packages (from jinja2->torch->medmnist) (3.0.3)
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
# Installing collected packages: fire, medmnist
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [medmnist]
# Successfully installed fire-0.7.1 medmnist-3.0.2

# %%
import medmnist
from medmnist import INFO
from torchvision import transforms
from torch.utils.data import DataLoader

data_flag = 'pathmnist'
info = INFO[data_flag]
DataClass = getattr(medmnist, info['python_class'])

train_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

train_dataset = DataClass(
    split='train',
    transform=train_transform,
    download=True,
    size=224,
    mmap_mode='r'
)

val_dataset = DataClass(
    split='val',
    transform=test_transform,
    download=True,
    size=224,
    mmap_mode='r'
)

test_dataset = DataClass(
    split='test',
    transform=test_transform,
    download=True,
    size=224,
    mmap_mode='r'
)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4, pin_memory=True)
